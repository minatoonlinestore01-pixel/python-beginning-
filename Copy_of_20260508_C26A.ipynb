# %% [markdown]
# <a href="https://colab.research.google.com/github/minatoonlinestore01-pixel/python-beginning-/blob/main/Copy_of_20260508_C26A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('sugimura')
print('Hiroshi')
print("AI")
# Out:
# sugimura
# Hiroshi
# AI

# %% [markdown]
# https://colab.research.google.com/drive/1VtsQe5U06512NYENKHq6B9CkdNleW5S_?usp=sharing

# %%
a = 5
b = 4
sugimura = "sugimura"

# %%
a + b
# Out:
# 9

# %%
print('sugimura')
print(sugimura)
# Out:
# sugimura
# sugimura
