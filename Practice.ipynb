# %%
# Repeat exactly 3 times
for i in range(3):
    print("Hello!")
# Out:
# Hello!
# Hello!
# Hello!

# %%
from flask import Flask

app = Flask(__name__)

HOMEPAGE_HTML = """
<!DOCTYPE html>
<html lang="en">
<head>
<meta charset="UTF-8">
<meta name="viewport" content="width=device-width, initial-scale=1.0">
<title>My Website</title>
<style>
  * { margin: 0; padding: 0; box-sizing: border-box; }
  body {
    font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", Roboto, sans-serif;
    color: #222;
    line-height: 1.6;
  }
  header {
    background: #1f2937;
    color: #fff;
    padding: 1rem 2rem;
    display: flex;
    justify-content: space-between;
    align-items: center;
  }
  header .logo { font-size: 1.4rem; font-weight: bold; }
  nav a {
    color: #fff;
    text-decoration: none;
    margin-left: 1.5rem;
    font-size: 0.95rem;
  }
  nav a:hover { text-decoration: underline; }
  .hero {
    background: #f3f4f6;
    text-align: center;
    padding: 5rem 2rem;
  }
  .hero h1 { font-size: 2.5rem; margin-bottom: 1rem; }
  .hero p { font-size: 1.1rem; color: #555; margin-bottom: 2rem; }
  .btn {
    display: inline-block;
    background: #2563eb;
    color: #fff;
    padding: 0.8rem 1.6rem;
    border-radius: 6px;
    text-decoration: none;
    font-weight: bold;
  }
  .btn:hover { background: #1d4ed8; }
  section.features {
    display: flex;
    flex-wrap: wrap;
    justify-content: center;
    gap: 2rem;
    padding: 4rem 2rem;
    max-width: 1000px;
    margin: 0 auto;
  }
  .feature {
    flex: 1 1 250px;
    text-align: center;
    padding: 1.5rem;
  }
  .feature h3 { margin-bottom: 0.5rem; }
  footer {
    text-align: center;
    padding: 2rem;
    background: #1f2937;
    color: #ccc;
    font-size: 0.9rem;
  }
</style>
</head>
<body>

<header>
  <div class="logo">MySite</div>
  <nav>
    <a href="#home">Home</a>
    <a href="#about">About</a>
    <a href="#contact">Contact</a>
  </nav>
</header>

<section class="hero" id="home">
  <h1>Welcome to My Website</h1>
  <p>A simple homepage served with Python and Flask.</p>
  <a href="#about" class="btn">Learn More</a>
</section>

<section class="features" id="about">
  <div class="feature">
    <h3>Fast</h3>
    <p>Lightweight code that loads quickly on any device.</p>
  </div>
  <div class="feature">
    <h3>Responsive</h3>
    <p>Looks great on desktop, tablet, and mobile screens.</p>
  </div>
  <div class="feature">
    <h3>Simple</h3>
    <p>Easy to customize and extend for your own project.</p>
  </div>
</section>

<footer id="contact">
  <p>&copy; 2026 MySite. All rights reserved.</p>
</footer>

</body>
</html>
"""


@app.route("/")
def home():
    return HOMEPAGE_HTML


if __name__ == "__main__":
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug: * Restarting with watchdog (inotify)

# %%
shopping_list = ["milk", "eggs", "bread"]

# len(shopping_list) is 3, so range(3) gives us numbers 0, 1, 2
for i in range(len(shopping_list)):
    print(f"Item position {i} is {shopping_list[i]}")
# Out:
# Item position 0 is milk
# Item position 1 is eggs
# Item position 2 is bread

# %%
fruits = ["apple", "banana", "cherry"]
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %%
countdown = 3
while countdown > 0:
    print(countdown)
    countdown = countdown - 1  # Crucial! Otherwise, it loops forever.
print("Blast off!")
# Out:
# 3
# 2
# 1
# Blast off!

# %%
# This will loop 5 times, printing numbers 0 through 4
for i in range(5):
    print("Hello!", i)
# Out:
# Hello! 0
# Hello! 1
# Hello! 2
# Hello! 3
# Hello! 4

# %%
def multiply(x, y):
    return x * y

answer = multiply(4, 6)
print(answer)
# Out:
# 24

# %%
shopping_list = ["milk", "eggs", "bread"]

# len(shopping_list) is 3, so range(3) gives us numbers 0, 1, 2
for i in range(len(shopping_list)):
    print(f"Item position {i} is {shopping_list[i]}")
# Out:
# Item position 0 is milk
# Item position 1 is eggs
# Item position 2 is bread
